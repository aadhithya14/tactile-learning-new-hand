# %%
import glob
import sys
import os

# %%
# Notebook to stack videos


# First find all the video names given the task
task_name = 'plier_picking'
# Get the directories with the name plier_picking - traverse in eval_video and train_video
all_video_paths = glob.glob(os.path.join(f'/home/irmak/Workspace/tactile-learning/online_training_outs/*/videos/*{task_name}*/', f'*.mp4'), recursive=True)

# %%
len(all_video_paths)
# Out:
# 977

# %%
def create_xstack_filter(num_vertical, num_horizontal, stack_order='horizontal'):
    # If stack_order is horizontal then the videos will first stack horizontally
    xstack_filter = ''
    if stack_order == 'horizontal':
        for v in range(num_vertical):
            vertical_addition = '0' if v == 0 else '+'.join([f'w{(i)*num_horizontal}' for i in range(v)])
            for h in range(num_horizontal):
                horizontal_addition = '0' if h == 0 else '+'.join([f'h{(i)}' for i in range(h)])

                curr_filter = f'{vertical_addition}_{horizontal_addition}|'
                xstack_filter += curr_filter

    elif stack_order == 'vertical':
        for h in range(num_horizontal):
            horizontal_addition = '0' if h == 0 else '+'.join([f'h{(i)*num_vertical}' for i in range(h)])
            for v in range(num_vertical):
                vertical_addition = '0' if v == 0 else '+'.join([f'w{(i)}' for i in range(v)])

                curr_filter = f'{vertical_addition}_{horizontal_addition}|'
                xstack_filter += curr_filter

    return xstack_filter[:-1] # Dont get the last |

# %%
import re
escape_func = str.maketrans({"-":  r"\-",
                            "]":  r"\]",
                            "\\": r"\\",
                            "^":  r"\^",
                            "$":  r"\$",
                            "*":  r"\*",
                            ".":  r"\.",
                            "'": r"\'",
                            " ": r"\ "})

# %%
NUM_VIDEOS = 40
horz_size = 8
for i in range(0,len(all_video_paths), NUM_VIDEOS):
    print('i: {}'.format(i))
    curr_dump_videos = all_video_paths[i:i+NUM_VIDEOS]
    curr_video_len = len(curr_dump_videos)
    curr_video_len = horz_size * int(curr_video_len/horz_size)
    xstack_filter = create_xstack_filter(horz_size, int(curr_video_len/horz_size), 'vertical')
    input_strs = ' '.join([f'-i {video_path.translate(escape_func)}' for video_path in curr_dump_videos[:curr_video_len]])

    # print('input_strs: {}'.format(input_strs))
    # for video_path in

    vstack_strs = ''.join([f'[{i}:v]' for i in range(curr_video_len)])
    ffmpeg_str = f'ffmpeg {input_strs} -filter_complex "{vstack_strs}xstack=inputs={curr_video_len}:layout={xstack_filter}" stacked_videos/{task_name}_output_{i}.mp4'
    os.system(ffmpeg_str) 

    # break
# Out:
# i: 0
# ffmpeg version 5.1.2 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 10.4.0 (conda-forge gcc 10.4.0-18)
#   configuration: --prefix=/home/irmak/miniconda3/envs/tactile_learning --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1666357487580/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1666357487580/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1666357487580/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1666357487580/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libfontconfig --enable-libopenh264 --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-pthreads --enable-vaapi --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1666357487580/_build_env/bin/pkg-config
#   libavutil      57. 28.100 / 57. 28.100
#   libavcodec     59. 37.100 / 59. 37.100
#   libavformat    59. 27.100 / 59. 27.100
#   libavdevice    59.  7.100 / 59.  7.100
#   libavfilter     8. 44.100 /  8. 44.100
#   libswscale      6.  7.100 /  6.  7.100
#   libswresample   4.  7.100 /  4.  7.100
#   libpostproc    56.  6.100 / 56.  6.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T05-33_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'features']/20230605T053509_e1_f49_r-10.0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 153 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 148 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T05-33_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'features']/20230605T053648_e2_f98_r-9.84000015258789.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 165 kb/s
#   Stream #1:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 160 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #2, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T05-33_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'features']/20230605T054110_e5_f245_r-10.0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 161 kb/s
#   Stream #2:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 157 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #3, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T05-33_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'features']/20230605T053936_e4_f196_r-8.229999542236328.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 165 kb/s
#   Stream #3:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 161 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #4, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T05-33_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'features']/20230605T053812_e3_f147_r-9.069999694824219.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 162 kb/s
#   Stream #4:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 158 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #5, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T11-12_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230605T111345_e2_f98_r-8.069999694824219.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 156 kb/s
#   Stream #5:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 152 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #6, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T11-12_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230605T111613_e4_f196_r-7.5.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 162 kb/s
#   Stream #6:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 158 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #7, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T11-12_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230605T111718_e5_f245_r-8.25.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 161 kb/s
#   Stream #7:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 156 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #8, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T11-12_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230605T111927_e7_f343_r-7.329999923706055.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 164 kb/s
#   Stream #8:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 160 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #9, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T11-12_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230605T113152_e14_f686_r-8.619999885559082.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 167 kb/s
#   Stream #9:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 163 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #10, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T11-12_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230605T111509_e3_f147_r-8.220000267028809.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 164 kb/s
#   Stream #10:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 160 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #11, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T11-12_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230605T112947_e12_f588_r-7.880000114440918.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 166 kb/s
#   Stream #11:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 162 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #12, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T11-12_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230605T111308_e1_f49_r-10.0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 158 kb/s
#   Stream #12:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 153 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #13, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T11-12_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230605T112141_e9_f441_r-8.989999771118164.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 164 kb/s
#   Stream #13:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 159 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #14, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T11-12_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230605T112030_e8_f392_r-9.369999885559082.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 162 kb/s
#   Stream #14:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 158 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #15, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T11-12_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230605T111821_e6_f294_r-7.570000171661377.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 161 kb/s
#   Stream #15:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 156 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #16, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T11-12_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230605T113409_e16_f784_r-7.909999847412109.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 162 kb/s
#   Stream #16:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 157 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #17, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T11-12_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230605T113301_e15_f735_r-11.0600004196167.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 162 kb/s
#   Stream #17:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 158 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #18, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T11-12_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230605T112352_e11_f539_r-9.210000038146973.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 162 kb/s
#   Stream #18:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 158 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #19, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T11-12_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230605T112246_e10_f490_r-6.860000133514404.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 156 kb/s
#   Stream #19:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 152 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #20, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T11-12_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230605T113049_e13_f637_r-9.0600004196167.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 164 kb/s
#   Stream #20:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 160 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #21, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T231640_e21_f1029_r-13.489999771118164.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 146 kb/s
#   Stream #21:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 142 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #22, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T225911_e3_f147_r-18.479999542236328.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 176 kb/s
#   Stream #22:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 171 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #23, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T231819_e23_f1127_r-14.539999961853027.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 150 kb/s
#   Stream #23:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 145 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #24, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T231411_e18_f882_r-13.84000015258789.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 155 kb/s
#   Stream #24:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 151 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #25, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T231231_e16_f784_r-10.220000267028809.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 150 kb/s
#   Stream #25:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 146 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #26, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T230903_e13_f637_r-15.989999771118164.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 153 kb/s
#   Stream #26:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 149 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #27, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T230723_e12_f588_r-14.039999961853027.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 148 kb/s
#   Stream #27:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 144 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #28, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T230636_e11_f539_r-15.649999618530273.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 153 kb/s
#   Stream #28:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 149 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #29, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T232317_e29_f1421_r-9.229999542236328.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 148 kb/s
#   Stream #29:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 144 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #30, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T232012_e25_f1225_r-14.989999771118164.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 148 kb/s
#   Stream #30:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 143 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #31, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T230332_e8_f392_r-13.720000267028809.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 151 kb/s
#   Stream #31:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 146 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #32, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T231148_e15_f735_r-12.520000457763672.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 152 kb/s
#   Stream #32:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 148 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #33, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T232421_e30_f1470_r-11.859999656677246.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 143 kb/s
#   Stream #33:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 139 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #34, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T225021_e1_f49_r-10.0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 164 kb/s
#   Stream #34:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 160 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #35, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T232140_e27_f1323_r-14.670000076293945.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 147 kb/s
#   Stream #35:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 142 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #36, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T232054_e26_f1274_r-14.010000228881836.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 155 kb/s
#   Stream #36:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 150 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #37, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T231727_e22_f1078_r-12.4399995803833.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 149 kb/s
#   Stream #37:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 144 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #38, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T225111_e2_f98_r-13.199999809265137.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 168 kb/s
#   Stream #38:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 164 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #39, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T232224_e28_f1372_r-11.479999542236328.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 152 kb/s
#   Stream #39:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 148 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (h264) -> xstack
#   Stream #1:0 (h264) -> xstack
#   Stream #2:0 (h264) -> xstack
#   Stream #3:0 (h264) -> xstack
#   Stream #4:0 (h264) -> xstack
#   Stream #5:0 (h264) -> xstack
#   Stream #6:0 (h264) -> xstack
#   Stream #7:0 (h264) -> xstack
#   Stream #8:0 (h264) -> xstack
#   Stream #9:0 (h264) -> xstack
#   Stream #10:0 (h264) -> xstack
#   Stream #11:0 (h264) -> xstack
#   Stream #12:0 (h264) -> xstack
#   Stream #13:0 (h264) -> xstack
#   Stream #14:0 (h264) -> xstack
#   Stream #15:0 (h264) -> xstack
#   Stream #16:0 (h264) -> xstack
#   Stream #17:0 (h264) -> xstack
#   Stream #18:0 (h264) -> xstack
#   Stream #19:0 (h264) -> xstack
#   Stream #20:0 (h264) -> xstack
#   Stream #21:0 (h264) -> xstack
#   Stream #22:0 (h264) -> xstack
#   Stream #23:0 (h264) -> xstack
#   Stream #24:0 (h264) -> xstack
#   Stream #25:0 (h264) -> xstack
#   Stream #26:0 (h264) -> xstack
#   Stream #27:0 (h264) -> xstack
#   Stream #28:0 (h264) -> xstack
#   Stream #29:0 (h264) -> xstack
#   Stream #30:0 (h264) -> xstack
#   Stream #31:0 (h264) -> xstack
#   Stream #32:0 (h264) -> xstack
#   Stream #33:0 (h264) -> xstack
#   Stream #34:0 (h264) -> xstack
#   Stream #35:0 (h264) -> xstack
#   Stream #36:0 (h264) -> xstack
#   Stream #37:0 (h264) -> xstack
#   Stream #38:0 (h264) -> xstack
#   Stream #39:0 (h264) -> xstack
#   xstack:default -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x55b51539fb80] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55b51539fb80] profile High, level 5.0, 4:2:0, 8-bit
# [libx264 @ 0x55b51539fb80] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=40 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=20 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'stacked_videos/plier_picking_output_0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.27.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 2048x1280, q=2-31, 20 fps, 10240 tbn
#     Metadata:
#       encoder         : Lavc59.37.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   50 fps=0.0 q=-1.0 Lsize=    1710kB time=00:00:02.35 bitrate=5959.1kbits/s speed=2.54x
# video:1708kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.083929%
# [libx264 @ 0x55b51539fb80] frame I:1     Avg QP:22.04  size:255941
# [libx264 @ 0x55b51539fb80] frame P:13    Avg QP:21.80  size: 76807
# [libx264 @ 0x55b51539fb80] frame B:36    Avg QP:26.88  size: 13722
# [libx264 @ 0x55b51539fb80] consecutive B-frames:  2.0%  4.0%  6.0% 88.0%
# [libx264 @ 0x55b51539fb80] mb I  I16..4: 12.9% 42.2% 44.8%
# [libx264 @ 0x55b51539fb80] mb P  I16..4:  0.7%  2.1%  3.0%  P16..4: 36.9% 15.2% 11.1%  0.0%  0.0%    skip:31.1%
# [libx264 @ 0x55b51539fb80] mb B  I16..4:  0.0%  0.0%  0.1%  B16..8: 25.4%  5.8%  2.1%  direct: 1.2%  skip:65.5%  L0:39.9% L1:54.0% BI: 6.1%
# [libx264 @ 0x55b51539fb80] 8x8 transform intra:39.5% inter:55.6%
# [libx264 @ 0x55b51539fb80] coded y,uvDC,uvAC intra: 77.9% 88.3% 56.0% inter: 9.9% 15.6% 1.5%
# [libx264 @ 0x55b51539fb80] i16 v,h,dc,p:  6% 42%  2% 50%
# [libx264 @ 0x55b51539fb80] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 32% 11%  6%  4%  6%  5%  7%  9%
# [libx264 @ 0x55b51539fb80] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 26% 12%  7%  4%  6%  4%  9%  5%
# [libx264 @ 0x55b51539fb80] i8c dc,h,v,p: 36% 35% 20%  9%
# [libx264 @ 0x55b51539fb80] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55b51539fb80] ref P L0: 61.8% 15.7% 16.3%  6.1%
# [libx264 @ 0x55b51539fb80] ref B L0: 87.5% 10.4%  2.1%
# [libx264 @ 0x55b51539fb80] ref B L1: 95.2%  4.8%
# [libx264 @ 0x55b51539fb80] kb/s:5594.92
# ffmpeg version 5.1.2 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 10.4.0 (conda-forge gcc 10.4.0-18)
#   configuration: --prefix=/home/irmak/miniconda3/envs/tactile_learning --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1666357487580/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1666357487580/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1666357487580/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1666357487580/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libfontconfig --enable-libopenh264 --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-pthreads --enable-vaapi --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1666357487580/_build_env/bin/pkg-config
#   libavutil      57. 28.100 / 57. 28.100
#   libavcodec     59. 37.100 / 59. 37.100
#   libavformat    59. 27.100 / 59. 27.100
#   libavdevice    59.  7.100 / 59.  7.100
#   libavfilter     8. 44.100 /  8. 44.100
#   libswscale      6.  7.100 /  6.  7.100
#   libswresample   4.  7.100 /  4.  7.100
#   libpostproc    56.  6.100 / 56.  6.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T230550_e10_f490_r-11.539999961853027.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 150 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 146 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T230149_e6_f294_r-13.25.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 158 kb/s
#   Stream #1:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 153 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #2, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T230929_e14_f686_r-12.960000038146973.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 146 kb/s
#   Stream #2:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 141 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #3, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T230008_e4_f196_r-14.9399995803833.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 160 kb/s
#   Stream #3:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 155 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #4, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T230238_e7_f343_r-12.15999984741211.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 148 kb/s
#   Stream #4:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 144 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #5, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T231322_e17_f833_r-12.210000038146973.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 150 kb/s
#   Stream #5:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 146 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #6, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T230102_e5_f245_r-16.110000610351562.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 160 kb/s
#   Stream #6:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 155 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #7, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T231505_e19_f931_r-14.699999809265137.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 160 kb/s
#   Stream #7:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 155 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #8, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T231552_e20_f980_r-14.800000190734863.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 150 kb/s
#   Stream #8:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 145 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #9, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T230453_e9_f441_r-13.25.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 156 kb/s
#   Stream #9:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 152 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #10, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.04T22-49_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230604T231923_e24_f1176_r-9.369999885559082.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 151 kb/s
#   Stream #10:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 146 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #11, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T02-52_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230605T025456_e2_f98_r-13.510000228881836.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 173 kb/s
#   Stream #11:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 168 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #12, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T02-52_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230605T025332_e1_f49_r-10.0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 167 kb/s
#   Stream #12:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 163 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #13, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T02-52_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230605T030136_e5_f245_r-9.59000015258789.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 174 kb/s
#   Stream #13:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 169 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #14, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T02-52_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230605T030600_e8_f392_r-7.849999904632568.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 165 kb/s
#   Stream #14:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 160 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# i: 40
# Input #15, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T02-52_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230605T031045_e11_f539_r-10.449999809265137.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 167 kb/s
#   Stream #15:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 162 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #16, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T02-52_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230605T025640_e3_f147_r-10.869999885559082.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 173 kb/s
#   Stream #16:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 169 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #17, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/train_video/videos/2023.06.05T02-52_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'tactile', 'features']/20230605T030914_e10_f490_r-8.260000228881836.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 166 kb/s
#   Stream #17:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 161 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# ...
# [libx264 @ 0x5590674cf100] ref P L0: 61.6% 16.4% 16.0%  6.0%
# [libx264 @ 0x5590674cf100] ref B L0: 88.6%  9.5%  1.9%
# [libx264 @ 0x5590674cf100] ref B L1: 94.3%  5.7%
# [libx264 @ 0x5590674cf100] kb/s:5071.43
# ffmpeg version 5.1.2 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 10.4.0 (conda-forge gcc 10.4.0-18)
#   configuration: --prefix=/home/irmak/miniconda3/envs/tactile_learning --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1666357487580/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1666357487580/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1666357487580/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1666357487580/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libfontconfig --enable-libopenh264 --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-pthreads --enable-vaapi --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1666357487580/_build_env/bin/pkg-config
#   libavutil      57. 28.100 / 57. 28.100
#   libavcodec     59. 37.100 / 59. 37.100
#   libavformat    59. 27.100 / 59. 27.100
#   libavdevice    59.  7.100 / 59.  7.100
#   libavfilter     8. 44.100 /  8. 44.100
#   libswscale      6.  7.100 /  6.  7.100
#   libswresample   4.  7.100 /  4.  7.100
#   libpostproc    56.  6.100 / 56.  6.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/eval_video/videos/2023.06.07T07-53_plier_picking_reward_reprs_['image', 'tactile']_policy_reprs_['image', 'tactile', 'features']/plier_picking_eval_0_1.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 141 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 137 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/eval_video/videos/2023.06.07T07-53_plier_picking_reward_reprs_['image', 'tactile']_policy_reprs_['image', 'tactile', 'features']/plier_picking_eval_0_4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 143 kb/s
#   Stream #1:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 138 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #2, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/eval_video/videos/2023.06.07T07-53_plier_picking_reward_reprs_['image', 'tactile']_policy_reprs_['image', 'tactile', 'features']/plier_picking_eval_0_9.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 143 kb/s
#   Stream #2:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 139 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #3, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/eval_video/videos/2023.06.07T07-53_plier_picking_reward_reprs_['image', 'tactile']_policy_reprs_['image', 'tactile', 'features']/plier_picking_eval_0_6.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 142 kb/s
#   Stream #3:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 138 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #4, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/eval_video/videos/2023.06.07T07-53_plier_picking_reward_reprs_['image', 'tactile']_policy_reprs_['image', 'tactile', 'features']/plier_picking_eval_0_8.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 143 kb/s
#   Stream #4:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 138 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #5, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/eval_video/videos/2023.06.07T07-53_plier_picking_reward_reprs_['image', 'tactile']_policy_reprs_['image', 'tactile', 'features']/plier_picking_eval_0_2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 142 kb/s
#   Stream #5:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 137 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #6, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/eval_video/videos/2023.06.07T07-53_plier_picking_reward_reprs_['image', 'tactile']_policy_reprs_['image', 'tactile', 'features']/plier_picking_eval_0_5.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 141 kb/s
#   Stream #6:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 137 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #7, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/eval_video/videos/2023.06.07T06-55_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'features']/plier_picking_eval_0_3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 143 kb/s
#   Stream #7:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 139 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #8, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/eval_video/videos/2023.06.07T06-55_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'features']/plier_picking_eval_0_7.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 141 kb/s
#   Stream #8:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 136 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #9, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/eval_video/videos/2023.06.07T06-55_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'features']/plier_picking_eval_0_1.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 140 kb/s
#   Stream #9:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 135 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #10, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/eval_video/videos/2023.06.07T06-55_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'features']/plier_picking_eval_0_4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 144 kb/s
#   Stream #10:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 140 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #11, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/eval_video/videos/2023.06.07T06-55_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'features']/plier_picking_eval_0_9.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 144 kb/s
#   Stream #11:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 140 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #12, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/eval_video/videos/2023.06.07T06-55_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'features']/plier_picking_eval_0_10.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 148 kb/s
#   Stream #12:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 143 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #13, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/eval_video/videos/2023.06.07T06-55_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'features']/plier_picking_eval_0_6.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 148 kb/s
#   Stream #13:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 144 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #14, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/eval_video/videos/2023.06.07T06-55_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'features']/plier_picking_eval_0_8.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 142 kb/s
#   Stream #14:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 137 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #15, mov,mp4,m4a,3gp,3g2,mj2, from '/home/irmak/Workspace/tactile-learning/online_training_outs/eval_video/videos/2023.06.07T06-55_plier_picking_reward_reprs_['image']_policy_reprs_['image', 'features']/plier_picking_eval_0_2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 151 kb/s
#   Stream #15:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 256x256, 146 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# i: 960
# Stream mapping:
#   Stream #0:0 (h264) -> xstack
#   Stream #1:0 (h264) -> xstack
#   Stream #2:0 (h264) -> xstack
#   Stream #3:0 (h264) -> xstack
#   Stream #4:0 (h264) -> xstack
#   Stream #5:0 (h264) -> xstack
#   Stream #6:0 (h264) -> xstack
#   Stream #7:0 (h264) -> xstack
#   Stream #8:0 (h264) -> xstack
#   Stream #9:0 (h264) -> xstack
#   Stream #10:0 (h264) -> xstack
#   Stream #11:0 (h264) -> xstack
#   Stream #12:0 (h264) -> xstack
#   Stream #13:0 (h264) -> xstack
#   Stream #14:0 (h264) -> xstack
#   Stream #15:0 (h264) -> xstack
#   xstack:default -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x562f1ce75fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x562f1ce75fc0] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x562f1ce75fc0] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=20 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'stacked_videos/plier_picking_output_960.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.27.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 2048x512, q=2-31, 20 fps, 10240 tbn
#     Metadata:
#       encoder         : Lavc59.37.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   50 fps=0.0 q=-1.0 Lsize=     622kB time=00:00:02.35 bitrate=2167.6kbits/s speed=4.77x
# video:620kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.229814%
# [libx264 @ 0x562f1ce75fc0] frame I:1     Avg QP:24.05  size: 84462
# [libx264 @ 0x562f1ce75fc0] frame P:15    Avg QP:21.87  size: 27611
# [libx264 @ 0x562f1ce75fc0] frame B:34    Avg QP:26.52  size:  4000
# [libx264 @ 0x562f1ce75fc0] consecutive B-frames:  4.0% 16.0%  0.0% 80.0%
# [libx264 @ 0x562f1ce75fc0] mb I  I16..4: 11.0% 45.6% 43.4%
# [libx264 @ 0x562f1ce75fc0] mb P  I16..4:  0.6%  1.9%  2.3%  P16..4: 36.2% 14.5% 10.1%  0.0%  0.0%    skip:34.5%
# [libx264 @ 0x562f1ce75fc0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 25.1%  4.0%  1.3%  direct: 0.9%  skip:68.7%  L0:35.0% L1:59.9% BI: 5.2%
# [libx264 @ 0x562f1ce75fc0] 8x8 transform intra:42.7% inter:56.1%
# [libx264 @ 0x562f1ce75fc0] coded y,uvDC,uvAC intra: 76.3% 89.1% 54.4% inter: 9.0% 15.5% 1.7%
# [libx264 @ 0x562f1ce75fc0] i16 v,h,dc,p:  8% 35%  4% 53%
# [libx264 @ 0x562f1ce75fc0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 31% 13%  6%  5%  5%  5%  8%  9%
# [libx264 @ 0x562f1ce75fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 27% 11%  7%  4%  6%  4%  8%  5%
# [libx264 @ 0x562f1ce75fc0] i8c dc,h,v,p: 39% 31% 21%  9%
# [libx264 @ 0x562f1ce75fc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x562f1ce75fc0] ref P L0: 65.6% 15.4% 13.7%  5.2%
# [libx264 @ 0x562f1ce75fc0] ref B L0: 87.7% 10.7%  1.5%
# [libx264 @ 0x562f1ce75fc0] ref B L1: 94.7%  5.3%
# [libx264 @ 0x562f1ce75fc0] kb/s:2030.74
